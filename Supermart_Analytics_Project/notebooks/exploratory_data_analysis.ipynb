# %%
# Cell 1: Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cell 2: Load Cleaned Data
# Since this notebook is in the notebooks folder, if the cleaned data is in the data folder at the project root,
# use the correct relative path:
data = pd.read_csv('../data/cleaned_supermart_data.csv')
print("✅ Data Overview:")
print(data.head())

# Cell 3: Sales Distribution Plot
plt.figure(figsize=(8, 5))
sns.histplot(data['Sales'], bins=30, kde=True, color='skyblue')
plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# Cell 4: Sales by Category (Bar Chart)
plt.figure(figsize=(10, 6))
# Get the count of each category (assuming category is encoded as numbers)
category_counts = data['Category'].value_counts()
sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')
plt.title('Sales by Category (Count)')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# Cell 5: Yearly Sales Trend (Line Plot)
plt.figure(figsize=(10, 6))
# Group the data by Order_Year and sum up the Sales
yearly_sales = data.groupby('Order_Year')['Sales'].sum().reset_index()
sns.lineplot(x='Order_Year', y='Sales', data=yearly_sales, marker='o', color='coral')
plt.title('Yearly Sales Trend')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.show()

print("✅ Exploratory Data Analysis Completed!")
# Out:
# ✅ Data Overview:
#   Order_ID Customer_Name  Category  Sub_Category  City  Order_Date  Region  \
# 0      OD1        Harish         5            14    21  2017-08-11       2
# 1      OD2         Sudha         1            13     8  2017-08-11       3
# 2      OD3       Hussain         3             0    13  2017-12-06       4
# 3      OD4       Jackson         4            12     4  2016-11-10       3
# 4      OD5       Ridhesh         3            18    12  2016-11-10       3
#
#    Sales  Discount  Profit  State     Month  Order_Year
# 0   1254      0.12  401.28      0    August        2017
# 1    749      0.18  149.80      0    August        2017
# 2   2360      0.21  165.20      0  December        2017
# 3    896      0.25   89.60      0  November        2016
# 4   2355      0.26  918.45      0  November        2016
# C:\Users\ayesh\AppData\Local\Temp\ipykernel_17940\3613405666.py:25: FutureWarning:
#
# ...
